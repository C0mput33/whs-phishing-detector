# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import urllib.request
from urllib.parse import urlparse
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
data = pd.read_csv('model_data.csv')
val_data = pd.read_csv('valid_data.csv')
val_data['url'] = val_data['url'].apply(str)

# %%
print(f'정상 url 비율 = {round(data["Label"].value_counts()[0]/len(data) * 100,3)}%')
print(f'피싱 url 비율 = {round(data["Label"].value_counts()[1]/len(data) * 100,3)}%')
# Out:
# 정상 url 비율 = 51.725%
# 피싱 url 비율 = 48.275%

# %%
print(f'정상 url 비율 = {round(val_data["Label"].value_counts()[0]/len(val_data) * 100,3)}%')
print(f'피싱 url 비율 = {round(val_data["Label"].value_counts()[1]/len(val_data) * 100,3)}%')
# Out:
# 정상 url 비율 = 71.429%
# 피싱 url 비율 = 28.571%

# %%
#독립 변수
X_data = data['url']

# 종속 변수
y_data = data['Label']

# 검증용 데이터
shuffled_val_data = val_data.sample(frac=1, random_state=0).reset_index(drop=True)
X_val = shuffled_val_data['url']
y_val = shuffled_val_data['Label']

# %%
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2, random_state=0, stratify=y_data)

# %%
# 각 데이터의 크기 확인
print("훈련 데이터 크기:", X_train.shape, y_train.shape)
print("검증 데이터 크기:", X_val.shape, y_val.shape)
print("테스트 데이터 크기:", X_test.shape, y_test.shape)
# Out:
# 훈련 데이터 크기: (231995,) (231995,)
# 검증 데이터 크기: (70000,) (70000,)
# 테스트 데이터 크기: (57999,) (57999,)

# %%
print('--------훈련 데이터의 비율-----------')
print(f'정상 url = {round(y_train.value_counts()[0]/len(y_train) * 100,3)}%')
print(f'스팸 url = {round(y_train.value_counts()[1]/len(y_train) * 100,3)}%')

print('--------테스트 데이터의 비율-----------')
print(f'정상 url = {round(y_test.value_counts()[0]/len(y_test) * 100,3)}%')
print(f'스팸 url = {round(y_test.value_counts()[1]/len(y_test) * 100,3)}%')

print('--------검증 데이터의 비율-----------')
print(f'정상 url = {round(y_val.value_counts()[0]/len(y_val) * 100,3)}%')
print(f'스팸 url = {round(y_val.value_counts()[1]/len(y_val) * 100,3)}%')
# Out:
# --------훈련 데이터의 비율-----------
# 정상 url = 51.725%
# 스팸 url = 48.275%
# --------테스트 데이터의 비율-----------
# 정상 url = 51.725%
# 스팸 url = 48.275%
# --------검증 데이터의 비율-----------
# 정상 url = 71.429%
# 스팸 url = 28.571%

# %%
# URL을 구성 요소로 분리하는 함수
def tokenize_url(url):
    parsed_url = urlparse(url)
    scheme = parsed_url.scheme
    netloc = parsed_url.netloc
    path = parsed_url.path

    # 구성 요소를 리스트로 결합
    url_parts = [scheme] + netloc.split('.') + path.split('/')

    # 빈 문자열 제거
    url_parts = [part for part in url_parts if part]

    return url_parts

# URL 리스트를 구성 요소로 분리
X_train_list = [tokenize_url(url) for url in X_train]

# 구성 요소를 문자열로 결합
X_train_list = [' '.join(parts) for parts in X_train_list]

# Tokenizer 초기화 및 텍스트 적합화
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train_list)

# 텍스트를 시퀀스로 변환
X_train_encoded = tokenizer.texts_to_sequences(X_train_list)

print("토큰화된 URL 구성 요소:", X_train_encoded[:5])
# Out:
# 토큰화된 URL 구성 요소: [[1, 17, 10, 2, 22, 16, 14, 21, 28564, 28565, 28566, 8], [1, 28567, 39], [1, 27, 1261, 991, 1150, 5469, 5470, 27, 5], [1, 61, 2, 28568], [1, 59613, 38]]

# %%
word_to_index = tokenizer.word_index
word_to_index
# Out:
# {'https': 1,
#  'com': 2,
#  'ipfs': 3,
#  'http': 4,
#  'dev': 5,
#  'kr': 6,
#  'html': 7,
#  'pub': 8,
#  'www': 9,
#  'google': 10,
#  'cf': 11,
#  'pages': 12,
#  'r2': 13,
#  'e': 14,
#  'org': 15,
#  'd': 16,
#  'docs': 17,
#  'net': 18,
#  'go': 19,
#  'weeblysite': 20,
#  '2pacx': 21,
#  'presentation': 22,
#  'app': 23,
#  'cloudflare': 24,
#  'co': 25,
#  'io': 26,
#  'workers': 27,
#  'web': 28,
#  'php': 29,
#  'es': 30,
#  'webmail': 31,
#  'network': 32,
#  'firebaseapp': 33,
#  'ru': 34,
#  'eth': 35,
#  'aragon': 36,
#  'index': 37,
#  'in': 38,
#  'site': 39,
#  'my': 40,
#  'me': 41,
#  'jp': 42,
#  'top': 43,
#  'cn': 44,
#  'duckdns': 45,
#  'login': 46,
#  'new': 47,
#  'link': 48,
#  'ms': 49,
#  'wixsite': 50,
#  'adobe': 51,
#  'express': 52,
#  'weebly': 53,
#  'webpage': 54,
#  'id': 55,
#  'or': 56,
#  'att': 57,
#  'gov': 58,
#  'de': 59,
#  'edu': 60,
#  'tinyurl': 61,
#  'hs': 62,
#  'ir': 63,
#  'blogspot': 64,
#  'fr': 65,
#  't': 66,
#  'sites': 67,
#  'info': 68,
#  'view': 69,
#  'home': 70,
#  'wp': 71,
#  'ac': 72,
#  'page': 73,
#  'pl': 74,
#  'mail': 75,
#  'online': 76,
#  'br': 77,
#  'myshopify': 78,
#  'xyz': 79,
#  'ly': 80,
#  'uk': 81,
#  'ch': 82,
#  'webcindario': 83,
#  'au': 84,
#  'gne': 85,
#  'mybluehost': 86,
#  'ca': 87,
#  '1': 88,
#  'webwave': 89,
#  'tw': 90,
#  'mx': 91,
#  'm': 92,
#  'github': 93,
#  'vercel': 94,
#  'do': 95,
#  'nftstorage': 96,
#  'htm': 97,
#  'it': 98,
#  'jne': 99,
#  'us': 100,
#  'aol': 101,
#  's': 102,
#  'webflow': 103,
#  'ar': 104,
#  'cc': 105,
#  'bt': 106,
#  'is': 107,
#  'gd': 108,
#  'content': 109,
#  'se': 110,
#  'p': 111,
#  'update': 112,
#  'square': 113,
#  'tv': 114,
#  '43': 115,
#  'gwe': 116,
#  'za': 117,
#  'auth': 118,
#  '5c': 119,
#  'signin': 120,
#  'tr': 121,
#  'forms': 122,
#  'telstra': 123,
#  'vn': 124,
#  'start': 125,
#  'cl': 126,
#  'worker': 127,
#  'usps': 128,
#  'at': 129,
#  'main': 130,
#  'bit': 131,
#  '2': 132,
#  'to': 133,
#  'best': 134,
#  'outlook': 135,
#  'world': 136,
#  'v3': 137,
#  'identifier': 138,
#  'school': 139,
#  'godaddysites': 140,
#  'microsoft': 141,
#  'cloud': 142,
#  'gyo6': 143,
#  'sign': 144,
#  'practice': 145,
#  'secure': 146,
#  'admin': 147,
#  'club': 148,
#  'live': 149,
#  'shop': 150,
#  'eu': 151,
#  'a': 152,
#  'hubside': 153,
#  'ua': 154,
#  '0': 155,
#  '7': 156,
#  'sa': 157,
#  'dweb': 158,
#  'gr': 159,
#  'biz': 160,
#  'ukit': 161,
#  'kvadtc': 162,
#  're': 163,
#  'pe': 164,
#  'email': 165,
#  'hello': 166,
#  'glitch': 167,
#  'aeon': 168,
#  'xn': 169,
#  'pro': 170,
#  'test': 171,
#  'support': 172,
#  'fi': 173,
#  'netlify': 174,
#  'i': 175,
#  'case': 176,
#  'account': 177,
#  'form': 178,
#  'az': 179,
#  'free': 180,
#  'sharepoint': 181,
#  'business': 182,
#  'b': 183,
#  'shorturl': 184,
#  'il': 185,
#  'cnees': 186,
#  'office': 187,
#  'nl': 188,
#  'mbr': 189,
#  'includes': 190,
#  'service': 191,
#  'sky': 192,
#  'cprapid': 193,
#  'myportfolio': 194,
#  'ng': 195,
#  'review': 196,
#  'seoul': 197,
#  '20': 198,
#  'l': 199,
#  'cos': 200,
#  'host': 201,
#  'myqcloud': 202,
#  'news': 203,
#  'owa': 204,
#  'help': 205,
#  'hk': 206,
#  'hotmail': 207,
#  'verify': 208,
#  'sg': 209,
#  'cz': 210,
#  'ws': 211,
#  'gob': 212,
#  'appeal': 213,
#  'mockplus': 214,
#  'finance': 215,
#  'h': 216,
#  'post': 217,
#  'btinternet': 218,
#  'click': 219,
#  'qrco': 220,
#  '4': 221,
#  'icees': 222,
#  'th': 223,
#  'ap': 224,
#  'flowcode': 225,
#  'inicio': 226,
#  'amp': 227,
#  'aeno': 228,
#  'pdf': 229,
#  'ae': 230,
#  'public': 231,
#  'so': 232,
#  'en': 233,
#  'aspx': 234,
#  'pk': 235,
#  'almardoof': 236,
#  'payment': 237,
#  'r': 238,
#  'dropbox': 239,
#  'c': 240,
#  'pt': 241,
#  'ro': 242,
#  'meta': 243,
#  'ai': 244,
#  'server': 245,
#  'storage': 246,
#  'alkhudharigroup': 247,
#  'wallet': 248,
#  'tw1': 249,
#  'dhl': 250,
#  'g': 251,
#  'vip': 252,
#  'telegram': 253,
#  'interactivelogin': 254,
#  'example': 255,
#  'icu': 256,
#  'ktt55': 257,
#  'djsch': 258,
#  'no': 259,
#  'scl': 260,
#  'windows': 261,
#  'website': 262,
#  'user': 263,
#  'wordpress': 264,
#  'f': 265,
#  'o': 266,
#  'dreamwp': 267,
#  'center': 268,
#  '156': 269,
#  'jsp': 270,
#  'your': 271,
#  'verification': 272,
#  'mofa': 273,
#  'juno': 274,
#  'facebook': 275,
#  '10': 276,
#  'open': 277,
#  'yahoo': 278,
#  'store': 279,
#  'jemi': 280,
#  '134': 281,
#  'be': 282,
#  'preview': 283,
#  'mobile': 284,
#  'plugins': 285,
#  'dk': 286,
#  'run': 287,
#  'art': 288,
#  'css': 289,
#  'response': 290,
#  'sc': 291,
#  'bitly': 292,
#  'hu': 293,
#  'paper': 294,
#  'inc': 295,
#  'pg': 296,
#  'rp': 297,
#  'work': 298,
#  'k': 299,
#  'address': 300,
#  '92': 301,
#  'ph': 302,
#  'nz': 303,
#  'koreapost': 304,
#  'js': 305,
#  'kz': 306,
#  'ee': 307,
#  'sviluppo': 308,
#  'tech': 309,
#  'portal': 310,
#  'daegu': 311,
#  '24': 312,
#  'wallets': 313,
#  'index2': 314,
#  'gg': 315,
#  'confirmation': 316,
#  'metafb': 317,
#  'usp': 318,
#  'reagan': 319,
#  'log': 320,
#  'track': 321,
#  'by': 322,
#  'health': 323,
#  'one': 324,
#  'walletpage': 325,
#  'ne': 326,
#  'netflix': 327,
#  'doc': 328,
#  '3': 329,
#  'orange': 330,
#  'ionos': 331,
#  'yolasite': 332,
#  'ourtime': 333,
#  'v': 334,
#  'szczecin': 335,
#  'media': 336,
#  'me2': 337,
#  'grmlbfao': 338,
#  'lib': 339,
#  'zuza': 340,
#  'stefek': 341,
#  'file': 342,
#  'viewform': 343,
#  'share': 344,
#  'group': 345,
#  'next': 346,
#  'bio': 347,
#  'unknown': 348,
#  'request': 349,
#  'delivery': 350,
#  'appspot': 351,
#  'security': 352,
#  'su': 353,
#  '159': 354,
#  'script': 355,
#  'newburycafe': 356,
#  'w': 357,
#  'incheon': 358,
#  'u': 359,
#  'ad': 360,
#  'sbb': 361,
#  'lt': 362,
#  'boxmode': 363,
#  'cnems': 364,
#  'aruba': 365,
#  'formstack': 366,
#  'gitbook': 367,
#  'blog': 368,
#  'codeanyapp': 369,
#  'tumblr': 370,
#  'connect': 371,
#  'images': 372,
#  'optikgeneral': 373,
#  'nts': 374,
#  'bg': 375,
#  'cyou': 376,
#  'access': 377,
#  'accueil': 378,
#  'macros': 379,
#  'type': 380,
#  'themes': 381,
#  'exec': 382,
#  'z': 383,
#  'gen': 384,
#  'allegrolokalnie': 385,
#  'c3': 386,
#  'violation': 387,
#  'flow': 388,
#  'on': 389,
#  'module': 390,
#  'qa': 391,
#  'voice': 392,
#  'pass': 393,
#  '6': 394,
#  'wpenginepowered': 395,
#  'ads': 396,
#  'onedrive': 397,
#  'for': 398,
#  'sk': 399,
#  'hr': 400,
#  'icems': 401,
#  'li': 402,
#  'netzero': 403,
#  'uz': 404,
#  'rs': 405,
#  'domain': 406,
#  'data': 407,
#  'council': 408,
#  'w3s': 409,
#  'terra': 410,
#  'brizy': 411,
#  'swiss': 412,
#  'life': 413,
#  'instant': 414,
#  'icehs': 415,
#  'n': 416,
#  '128': 417,
#  'fb': 418,
#  'billiardpg': 419,
#  'zya': 420,
#  '226': 421,
#  'studio': 422,
#  'tracking': 423,
#  '1318439371': 424,
#  'ff': 425,
#  'responsepage': 426,
#  '2023': 427,
#  '129': 428,
#  'cfd': 429,
#  'korzo': 430,
#  'submit': 431,
#  'eg': 432,
#  'uploads': 433,
#  'document': 434,
#  'blue': 435,
#  'ec': 436,
#  'clicketcloud': 437,
#  'check': 438,
#  'nic': 439,
#  'screen': 440,
#  'manage': 441,
#  'apps': 442,
#  'tour': 443,
#  'im': 444,
#  'x': 445,
#  'connection': 446,
#  'busan': 447,
#  'linkup': 448,
#  'pw': 449,
#  '9': 450,
#  'replit': 451,
#  'well': 452,
#  'bd': 453,
#  'digital': 454,
#  'xapz': 455,
#  'la': 456,
#  'trackconfirmaction': 457,
#  'hstn': 458,
#  '94': 459,
#  'the': 460,
#  'internet': 461,
#  'homes': 462,
#  'base': 463,
#  'chat': 464,
#  'community': 465,
#  '12': 466,
#  'known': 467,
#  'om': 468,
#  's3': 469,
#  'pantheonsite': 470,
#  'alert': 471,
#  'space': 472,
#  '1vq': 473,
#  'lv': 474,
#  'currently': 475,
#  '167': 476,
#  'azurewebsites': 477,
#  'api': 478,
#  'dong': 479,
#  'hyperphp': 480,
#  'kvsecure': 481,
#  'dvosplt': 482,
#  'fleek': 483,
#  'eng': 484,
#  '37': 485,
#  'na': 486,
#  'brt': 487,
#  'global': 488,
#  'interac': 489,
#  'sp': 490,
#  'lk': 491,
#  'load': 492,
#  'services': 493,
#  'p1ai': 494,
#  'etransfer': 495,
#  'deposits': 496,
#  'daisychainconsulting': 497,
#  'fire': 498,
#  '000webhostapp': 499,
#  'cakeresume': 500,
#  'drawings': 501,
#  'pay': 502,
#  'gateway': 503,
#  'indexjs': 504,
#  '1vs': 505,
#  'googleapis': 506,
#  'ma': 507,
#  'list': 508,
#  'ui': 509,
#  'you': 510,
#  'cr': 511,
#  'with': 512,
#  'jb': 513,
#  'team': 514,
#  'now': 515,
#  'sparkasse': 516,
#  '01': 517,
#  'accounts': 518,
#  '5': 519,
#  'servicelogin': 520,
#  'attcom': 521,
#  'inpost': 522,
#  '237': 523,
#  '2024': 524,
#  'spo': 525,
#  'download': 526,
#  'doubleclick': 527,
#  'assets': 528,
#  'bank': 529,
#  'kw': 530,
#  'url': 531,
#  'ulsan': 532,
#  'd9': 533,
#  'session': 534,
#  'up': 535,
#  'ge': 536,
#  'fm': 537,
#  'english': 538,
#  'w3spaces': 539,
#  'core': 540,
#  '67': 541,
#  'mqumq3hc': 542,
#  'g2x1mi': 543,
#  'asp': 544,
#  'card': 545,
#  'servicecu': 546,
#  '78': 547,
#  'contact': 548,
#  'cnehs': 549,
#  '11': 550,
#  '25': 551,
#  '26': 552,
#  'cpanel': 553,
#  'away': 554,
#  'emv1': 555,
#  'millennium': 556,
#  'sh': 557,
#  'index1': 558,
#  'chfinal': 559,
#  'uy': 560,
#  'member': 561,
#  'setting': 562,
#  'roundcube': 563,
#  'water': 564,
#  'zimbra': 565,
#  'star': 566,
#  'gwangju': 567,
#  'vk': 568,
#  'tools': 569,
#  'design': 570,
#  'amazon': 571,
#  '86': 572,
#  'metamask': 573,
#  'mil': 574,
#  '8': 575,
#  '100': 576,
#  'fun': 577,
#  'j': 578,
#  'suite': 579,
#  'oferta': 580,
#  'hoster': 581,
#  'validacion': 582,
#  'zpr': 583,
#  'sitebeat': 584,
#  'crazydomains': 585,
#  'today': 586,
#  'updated': 587,
#  'hotm': 588,
#  'garena': 589,
#  'ink': 590,
#  'seo': 591,
#  'rf': 592,
#  'lab': 593,
#  '11e8fc9c032f': 594,
#  'q': 595,
#  'xxx': 596,
#  'ny': 597,
#  'ddm': 598,
#  'keep': 599,
#  'clients': 600,
#  'sbs': 601,
#  'old': 602,
#  'gt': 603,
#  '103': 604,
#  'ke': 605,
#  'cheongju': 606,
#  'sms': 607,
#  'ing': 608,
#  'ie': 609,
#  'tt': 610,
#  've': 611,
#  '130': 612,
#  '181': 613,
#  'dz': 614,
#  'rebrand': 615,
#  'cgi': 616,
#  'tgadminuser': 617,
#  'p0ypagtjbll': 618,
#  'sfr': 619,
#  '41': 620,
#  'adsmaneger': 621,
#  'dapps': 622,
#  '5chttps': 623,
#  'files': 624,
#  'credit': 625,
#  '0hi': 626,
#  'seocho': 627,
#  'fix': 628,
#  'dapp': 629,
#  'challenge': 630,
#  'servicos': 631,
#  'securely': 632,
#  'gumi': 633,
#  'cool': 634,
#  'bin': 635,
#  'dkb': 636,
#  'bill': 637,
#  'privacy': 638,
#  'chrome': 639,
#  'redirect': 640,
#  'a1gina': 641,
#  'csb': 642,
#  'fcyz': 643,
#  'al': 644,
#  'gm': 645,
#  'af': 646,
#  'qr': 647,
#  'client': 648,
#  'ba': 649,
#  'message': 650,
#  'true': 651,
#  'project': 652,
#  'buzz': 653,
#  'captcha': 654,
#  'intro': 655,
#  'caees': 656,
#  'jeju': 657,
#  'mailvalidation': 658,
#  'culture': 659,
#  'paas': 660,
#  'massivegrid': 661,
#  'tn': 662,
#  'get': 663,
#  'si': 664,
#  'chameleon': 665,
#  'paypay': 666,
#  'direct': 667,
#  'plus': 668,
#  'standard': 669,
#  'gb': 670,
#  'dse': 671,
#  'invoice': 672,
#  'remove': 673,
#  'korcham': 674,
#  'information': 675,
#  'squarespace': 676,
#  'grandculture': 677,
#  'library': 678,
#  'shared': 679,
#  'heke91': 680,
#  'museum': 681,
#  'atwola': 682,
#  'adlink': 683,
#  '5113': 684,
#  '5043043': 685,
#  '5112': 686,
#  'adid': 687,
#  '11146745': 688,
#  'yes': 689,
#  'dashboard': 690,
#  '52': 691,
#  'tokyo': 692,
#  '5b1kard': 693,
#  '210': 694,
#  'links': 695,
#  'prod': 696,
#  'sun': 697,
#  'am': 698,
#  'push': 699,
#  'bucket': 700,
#  'correos': 701,
#  'principal': 702,
#  'issue': 703,
#  'utility': 704,
#  'east': 705,
#  'node': 706,
#  'company': 707,
#  'green': 708,
#  'ghadirlouleh': 709,
#  '682ad3b65d944376b919745aae3c56d4': 710,
#  'dh': 711,
#  'dew4': 712,
#  'acme': 713,
#  'uspw': 714,
#  'alt': 715,
#  'loading': 716,
#  '0lx': 717,
#  'policy': 718,
#  'win': 719,
#  'templates': 720,
#  'dynv6': 721,
#  'games': 722,
#  '153': 723,
#  'vulkan': 724,
#  'inox': 725,
#  'mapo': 726,
#  'desktop': 727,
#  'usa': 728,
#  'keepo': 729,
#  'upgrade': 730,
#  'drive': 731,
#  '51': 732,
#  'py': 733,
#  'bonus': 734,
#  'dept': 735,
#  'y': 736,
#  '02': 737,
#  '15': 738,
#  'red': 739,
#  'trade': 740,
#  'chain': 741,
#  'windex': 742,
#  '28': 743,
#  'songpa': 744,
#  'taplink': 745,
#  'dongoffice': 746,
#  'changwon': 747,
#  'cs': 748,
#  'survey': 749,
#  'globalsources': 750,
#  'allegro': 751,
#  'video': 752,
#  'truist': 753,
#  'wepik': 754,
#  'builder': 755,
#  'gh': 756,
#  'lux': 757,
#  'aaeoncojpcb1e': 758,
#  'jeonju': 759,
#  'multi': 760,
#  'welcome': 761,
#  '207': 762,
#  'mobi': 763,
#  '29': 764,
#  'v0': 765,
#  '233': 766,
#  'cmd': 767,
#  'appurl': 768,
#  'auto': 769,
#  'forest': 770,
#  'broadband': 771,
#  'seongbuk': 772,
#  'money': 773,
#  'pory': 774,
#  'order': 775,
#  '211': 776,
#  'epocerd': 777,
#  'webydo': 778,
#  '75': 779,
#  'office365': 780,
#  'firebasestorage': 781,
#  '23': 782,
#  'sdk': 783,
#  'urest': 784,
#  'ologin': 785,
#  'ssl': 786,
#  'egybest': 787,
#  'maile': 788,
#  'elementor': 789,
#  'city': 790,
#  'bs': 791,
#  'cam': 792,
#  'uspz': 793,
#  'dawn': 794,
#  'cu': 795,
#  'mpva': 796,
#  'sofids': 797,
#  'comet': 798,
#  'muddy': 799,
#  'clouds': 800,
#  'here': 801,
#  '40': 802,
#  'paket': 803,
#  'll': 804,
#  'secureserver': 805,
#  'fhvgfbr4': 806,
#  'm0jqpm': 807,
#  'logn': 808,
#  '4f': 809,
#  'market': 810,
#  'customs': 811,
#  'backblazeb2': 812,
#  '49': 813,
#  'code': 814,
#  '365': 815,
#  'logon': 816,
#  'mafo': 817,
#  'gouv': 818,
#  'kg': 819,
#  '19': 820,
#  'ssp': 821,
#  'nt': 822,
#  '2010': 823,
#  'sparkling': 824,
#  'img': 825,
#  'jinju': 826,
#  'cdn': 827,
#  'porn': 828,
#  'surf': 829,
#  'name': 830,
#  'xet': 831,
#  '45': 832,
#  'sea': 833,
#  'che': 834,
#  'wl': 835,
#  'yak': 836,
#  'claim': 837,
#  'improvement': 838,
#  'bf1': 839,
#  '1vr': 840,
#  'miricanvas': 841,
#  'device': 842,
#  'systeme': 843,
#  'asia': 844,
#  'papert': 845,
#  'surl': 846,
#  'tg': 847,
#  'details': 848,
#  'centrum': 849,
#  'rep': 850,
#  'confirm': 851,
#  'editor': 852,
#  'credentials': 853,
#  'instagram': 854,
#  'application': 855,
#  'proxy': 856,
#  'swisspass': 857,
#  'zip': 858,
#  'clone': 859,
#  'ygs': 860,
#  'mi': 861,
#  'wcomhost': 862,
#  'recovery': 863,
#  'contato1': 864,
#  'personal': 865,
#  'bnid': 866,
#  'guid': 867,
#  '9slkin1gpn6fu': 868,
#  'dsedg7ftyfggyz9oejmo': 869,
#  'em3lgw': 870,
#  'mvsy6ewtm': 871,
#  'itime': 872,
#  '739915162': 873,
#  'darla': 874,
#  'ysd': 875,
#  'kvmn': 876,
#  'y963896142': 877,
#  'kvy': 878,
#  'untrusted': 879,
#  'fido': 880,
#  '1fa': 881,
#  'rcscore': 882,
#  'threshold': 883,
#  'kvpgcolo': 884,
#  'kvssp': 885,
#  'dvmktname': 886,
#  'dvbrand': 887,
#  'dvtype': 888,
#  'dvmodel': 889,
#  'kvrepo': 890,
#  'dvosversion': 891,
#  'crmcc': 892,
#  'crmnc': 893,
#  'gdpr': 894,
#  '1ynn': 895,
#  'nodecode': 896,
#  'adclntid': 897,
#  '1004': 898,
#  'spaceid': 899,
#  '794200019': 900,
#  'trackclk': 901,
#  'n51901': 902,
#  '3020245oath': 903,
#  'index3': 904,
#  'apply': 905,
#  'rcl': 906,
#  'creator': 907,
#  'twint': 908,
#  'wiki': 909,
#  'zone': 910,
#  '191': 911,
#  'mt': 912,
#  'tiny': 913,
#  'royalmail': 914,
#  'nonsan': 915,
#  'fyfyvfytvghv': 916,
#  'all': 917,
#  'subeservicios': 918,
#  'mouse': 919,
#  'safe': 920,
#  'robos': 921,
#  'gimhae': 922,
#  'apptuts': 923,
#  '34': 924,
#  'academy': 925,
#  'liveblog365': 926,
#  '900': 927,
#  'bafybeihhl6v6ahuhbpbsaffarzbsridd5ft27wql6dd7ukhcw7woaxo5qi': 928,
#  'ts': 929,
#  'demo': 930,
#  '1320008508': 931,
#  'wixstudio': 932,
#  'tk': 933,
#  'lx': 934,
#  'bar': 935,
#  'mayor': 936,
#  'and': 937,
#  'customer': 938,
#  'irsid': 939,
#  'linkedin': 940,
#  'lang': 941,
#  'sen': 942,
#  '90': 943,
#  'cox': 944,
#  'morning': 945,
#  'cyber': 946,
#  'po': 947,
#  'daejeon': 948,
#  'ht': 949,
#  'ice': 950,
#  'error': 951,
#  'fixed': 952,
#  'mk': 953,
#  'uspd': 954,
#  'fit': 955,
#  'attnet': 956,
#  'chungbuk': 957,
#  'bucheon': 958,
#  'ups': 959,
#  'np': 960,
#  'jotform': 961,
#  'linkby': 962,
#  'areautenti': 963,
#  'suwon': 964,
#  '88': 965,
#  'paypal': 966,
#  'icbp': 967,
#  'bitrix': 968,
#  'china': 969,
#  'hc': 970,
#  'mof': 971,
#  'univ': 972,
#  'receive': 973,
#  'settings': 974,
#  'gc': 975,
#  'gy': 976,
#  'travefy': 977,
#  '197': 978,
#  'tree': 979,
#  'bo': 980,
#  'indexx': 981,
#  'herokuapp': 982,
#  'colors': 983,
#  'mlg': 984,
#  'as': 985,
#  'espace': 986,
#  'qmqatmvxk96exppngqvclbmf2pvdmucdtjgf3ugvawkbhw': 987,
#  'bing': 988,
#  '215': 989,
#  'checkpoint': 990,
#  'long': 991,
#  'ggpolice': 992,
#  'identifiez': 993,
#  'bet': 994,
#  '22': 995,
#  'st': 996,
#  'ls': 997,
#  'law': 998,
#  'uspc': 999,
#  'blocks': 1000,
#  ...}

# %%
threshold = 2
total_cnt = len(word_to_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합(vocabulary)에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 등장 빈도가 1번 이하인 희귀 단어의 수: 110452
# 단어 집합(vocabulary)에서 희귀 단어의 비율: 64.9473139523944
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 9.86181212985392

# %%
vocab_size = len(word_to_index) + 1
print('단어 집합의 크기: {}'.format((vocab_size)))
# Out:
# 단어 집합의 크기: 170065

# %%
print('url 최대 길이 : %d' % max(len(sample) for sample in X_train_encoded))
print('url 평균 길이 : %f' % (sum(map(len, X_train_encoded))/len(X_train_encoded)))
# Out:
# url 최대 길이 : 560
# url 평균 길이 : 4.827677

# %%
max_len = 560
X_train_padded = pad_sequences(X_train_encoded, maxlen = max_len)
print("훈련 데이터의 크기(shape):", X_train_padded.shape)
# Out:
# 훈련 데이터의 크기(shape): (231995, 560)

# %%
from tensorflow.keras.layers import Dense, Conv1D, GlobalMaxPooling1D, Embedding, Dropout, MaxPooling1D
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

embedding_dim = 32
dropout_ratio = 0.3
num_filters = 32
kernel_size = 5

model = Sequential()
model.add(Embedding(vocab_size, embedding_dim))
model.add(Dropout(dropout_ratio))
model.add(Conv1D(num_filters, kernel_size, padding='valid', activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dropout(dropout_ratio))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=3)
mc = ModelCheckpoint('best_model.keras', monitor = 'val_acc', mode='max', verbose=1, save_best_only=True)

history = model.fit(X_train_padded, y_train, epochs=10, batch_size=64, validation_split=0.2, callbacks=[es, mc])
# Out:
# Epoch 1/10
# 2900/2900 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9303 - loss: 0.2021
# Epoch 1: val_acc improved from -inf to 0.98017, saving model to best_model.keras
# 2900/2900 ━━━━━━━━━━━━━━━━━━━━ 83s 28ms/step - acc: 0.9303 - loss: 0.2020 - val_acc: 0.9802 - val_loss: 0.0689
# Epoch 2/10
# 2899/2900 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.9882 - loss: 0.0393
# Epoch 2: val_acc improved from 0.98017 to 0.98871, saving model to best_model.keras
# 2900/2900 ━━━━━━━━━━━━━━━━━━━━ 80s 28ms/step - acc: 0.9882 - loss: 0.0393 - val_acc: 0.9887 - val_loss: 0.0420
# Epoch 3/10
# 2899/2900 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.9977 - loss: 0.0085
# Epoch 3: val_acc did not improve from 0.98871
# 2900/2900 ━━━━━━━━━━━━━━━━━━━━ 80s 28ms/step - acc: 0.9977 - loss: 0.0085 - val_acc: 0.9886 - val_loss: 0.0488
# Epoch 4/10
# 2899/2900 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.9991 - loss: 0.0035
# Epoch 4: val_acc improved from 0.98871 to 0.98983, saving model to best_model.keras
# 2900/2900 ━━━━━━━━━━━━━━━━━━━━ 82s 28ms/step - acc: 0.9991 - loss: 0.0035 - val_acc: 0.9898 - val_loss: 0.0431
# Epoch 5/10
# 2899/2900 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.9995 - loss: 0.0019
# Epoch 5: val_acc did not improve from 0.98983
# 2900/2900 ━━━━━━━━━━━━━━━━━━━━ 80s 27ms/step - acc: 0.9995 - loss: 0.0019 - val_acc: 0.9891 - val_loss: 0.0472
# Epoch 5: early stopping

# %%
X_test_encoded = tokenizer.texts_to_sequences(X_test)
X_test_padded = pad_sequences(X_test_encoded, maxlen = max_len)
print("\n 테스트 정확도: %.4f" % (model.evaluate(X_test_padded, y_test)[1]))
# Out:
# 1813/1813 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - acc: 0.9664 - loss: 0.1409
#
#  테스트 정확도: 0.9671

# %%
X_val_encoded = tokenizer.texts_to_sequences(X_val)
X_val_padded = pad_sequences(X_val_encoded, maxlen = max_len)
print("\n 검증 데이터 정확도: %.4f" % (model.evaluate(X_val_padded, y_val)[1]))
# Out:
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - acc: 0.9420 - loss: 0.2327
#
#  검증 데이터 정확도: 0.9428
